# %% [markdown]
# # Causal Discovery
#
# NOTEARS and PCMCI graph recovery on synthetic data.

# %%
import sys
sys.path.insert(0, '../src')

from causal_ml.evaluation.runner import run_discovery_benchmark
import yaml

with open('../configs/discovery_benchmark.yaml') as f:
    cfg = yaml.safe_load(f)
with open('../configs/default.yaml') as f:
    defaults = yaml.safe_load(f)
cfg = {**defaults, **cfg, 'sample_sizes': [1000], 'seeds': [42]}

results = run_discovery_benchmark(cfg)
for row in results['results']:
    print(row)
